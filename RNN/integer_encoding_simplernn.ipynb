# %%
import numpy as np

docs = [
    'go india go strong and fearless',
    'india india rising with pride',
    'hip hip hurray the crowd goes wild',
    'jeetega bhai jeetega india jeetega again',
    'kohli kohli batting with passion',
    'dhoni dhoni calm mind sharp finish',
    'inquilab zindabad echoes through generations'
]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token='<rnn>')

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index
# Out:
# {'<rnn>': 1,
#  'india': 2,
#  'jeetega': 3,
#  'go': 4,
#  'with': 5,
#  'hip': 6,
#  'kohli': 7,
#  'dhoni': 8,
#  'strong': 9,
#  'and': 10,
#  'fearless': 11,
#  'rising': 12,
#  'pride': 13,
#  'hurray': 14,
#  'the': 15,
#  'crowd': 16,
#  'goes': 17,
#  'wild': 18,
#  'bhai': 19,
#  'again': 20,
#  'batting': 21,
#  'passion': 22,
#  'calm': 23,
#  'mind': 24,
#  'sharp': 25,
#  'finish': 26,
#  'inquilab': 27,
#  'zindabad': 28,
#  'echoes': 29,
#  'through': 30,
#  'generations': 31}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('go', 2),
#              ('india', 4),
#              ('strong', 1),
#              ('and', 1),
#              ('fearless', 1),
#              ('rising', 1),
#              ('with', 2),
#              ('pride', 1),
#              ('hip', 2),
#              ('hurray', 1),
#              ('the', 1),
#              ('crowd', 1),
#              ('goes', 1),
#              ('wild', 1),
#              ('jeetega', 3),
#              ('bhai', 1),
#              ('again', 1),
#              ('kohli', 2),
#              ('batting', 1),
#              ('passion', 1),
#              ('dhoni', 2),
#              ('calm', 1),
#              ('mind', 1),
#              ('sharp', 1),
#              ('finish', 1),
#              ('inquilab', 1),
#              ('zindabad', 1),
#              ('echoes', 1),
#              ('through', 1),
#              ('generations', 1)])

# %%
tokenizer.document_count
# Out:
# 7

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[4, 2, 4, 9, 10, 11],
#  [2, 2, 12, 5, 13],
#  [6, 6, 14, 15, 16, 17, 18],
#  [3, 19, 3, 2, 3, 20],
#  [7, 7, 21, 5, 22],
#  [8, 8, 23, 24, 25, 26],
#  [27, 28, 29, 30, 31]]

# %%
from keras.utils import pad_sequences

# %%
sequences = pad_sequences(sequences, padding='post')

# %%
sequences
# Out:
# array([[ 4,  2,  4,  9, 10, 11,  0],
#        [ 2,  2, 12,  5, 13,  0,  0],
#        [ 6,  6, 14, 15, 16, 17, 18],
#        [ 3, 19,  3,  2,  3, 20,  0],
#        [ 7,  7, 21,  5, 22,  0,  0],
#        [ 8,  8, 23, 24, 25, 26,  0],
#        [27, 28, 29, 30, 31,  0,  0]], dtype=int32)

# %%
sequences.shape
# Out:
# (7, 7)

# %% [markdown]
# **IMDb Dataset**

# %%
from keras.datasets import imdb
from keras import Sequential
from keras.layers import Dense, SimpleRNN, Flatten

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data()

# %%
X_train.shape
# Out:
# (25000,)

# %%
print(len(X_train[0]))
print(len(X_train[1]))
print(len(X_train[2]))
# Out:
# 218
# 189
# 141

# %%
y_train.shape
# Out:
# (25000,)

# %%
X_train = pad_sequences(X_train, padding='post', maxlen=100)
X_test = pad_sequences(X_test, padding='post', maxlen=100)

# %%
X_train.shape
# Out:
# (25000, 100)

# %%
print(len(X_train[0]))
print(len(X_train[1]))
print(len(X_train[2]))
# Out:
# 100
# 100
# 100

# %%
model = Sequential()

model.add(SimpleRNN(32, input_shape=(100, 1), return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 32)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.5068 - loss: 0.6968 - val_accuracy: 0.5090 - val_loss: 0.6928
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.5167 - loss: 0.6931 - val_accuracy: 0.5066 - val_loss: 0.6934
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.5227 - loss: 0.6919 - val_accuracy: 0.5053 - val_loss: 0.6927
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.5100 - loss: 0.6930 - val_accuracy: 0.5144 - val_loss: 0.6925
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.5058 - loss: 0.6931 - val_accuracy: 0.5052 - val_loss: 0.6932
