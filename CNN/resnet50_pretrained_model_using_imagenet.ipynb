# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1_path = '/content/012.jpeg'
img1 = image.load_img(img1_path, target_size=(224, 224))
plt.imshow(cv2.imread(img1_path))
x1 = image.img_to_array(img1)
x1 = np.expand_dims(x1, axis=0)
x1 = preprocess_input(x1)

# %%
pred1 = model.predict(x1)
print('Predicted', decode_predictions(pred1, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predicted [('n02099601', 'golden_retriever', np.float32(0.8652838)), ('n02099712', 'Labrador_retriever', np.float32(0.09073083)), ('n02104029', 'kuvasz', np.float32(0.017590417))]

# %%
img1_path = '/content/013.jpeg'
img1 = image.load_img(img1_path, target_size=(224, 224))
plt.imshow(cv2.imread(img1_path))
x1 = image.img_to_array(img1)
x1 = np.expand_dims(x1, axis=0)
x1 = preprocess_input(x1)

pred1 = model.predict(x1)
print('Predicted', decode_predictions(pred1, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Predicted [('n02089973', 'English_foxhound', np.float32(0.5259807)), ('n02089867', 'Walker_hound', np.float32(0.27213714)), ('n02088364', 'beagle', np.float32(0.14267392))]

# %%
img1_path = '/content/014.jpeg'
img1 = image.load_img(img1_path, target_size=(224, 224))
plt.imshow(cv2.imread(img1_path))
x1 = image.img_to_array(img1)
x1 = np.expand_dims(x1, axis=0)
x1 = preprocess_input(x1)

pred1 = model.predict(x1)
print('Predicted', decode_predictions(pred1, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# Predicted [('n02124075', 'Egyptian_cat', np.float32(0.4466443)), ('n02123045', 'tabby', np.float32(0.12929364)), ('n02127052', 'lynx', np.float32(0.12371783))]

# %%
img1_path = '/content/015.jpeg'
img1 = image.load_img(img1_path, target_size=(224, 224))
plt.imshow(cv2.imread(img1_path))
x1 = image.img_to_array(img1)
x1 = np.expand_dims(x1, axis=0)
x1 = preprocess_input(x1)

pred1 = model.predict(x1)
print('Predicted', decode_predictions(pred1, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# Predicted [('n02096294', 'Australian_terrier', np.float32(0.23749846)), ('n02389026', 'sorrel', np.float32(0.19360413)), ('n02100877', 'Irish_setter', np.float32(0.09906652))]
